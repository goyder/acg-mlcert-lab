# %% [markdown]
# # Sagemaker AutoML Experiment
#
# We will test the Sagemaker AutoML tool for the ACloudGuru lab.

# %%
import os
import pandas as pd
import boto3
import datetime
from os.path import join

# %% [markdown]
# ## Data upload
#
# The first step is to upload our dataset to S3.
#
# In this instance, we will upload the entire, raw dataset.
#
# From a previous EDA we noted:
#
# * It's actually relatively clean - there are no missing values to infer
# * We have a lot of features to work with
#
# It will be interested to examine how AutoML deals with it with little help.

# %%
root_dir = os.path.abspath("..")
data_dir = join(root_dir, "data")
raw_data_dir = join(data_dir, "raw")
processed_data_dir = join(data_dir, "processed")

# %% [markdown]
# We'll read in our full dataset to begin. This is a `.csv` file - we make no further assumptions:

# %%
df_ufo = pd.read_csv(join(raw_data_dir, "ufo_fullset.csv"))

# %% [markdown]
# The data is succesfully read in. We will output under the processed folder in a specific format to ensure it is ready for analysis:

# %%
df_ufo.to_csv(join(processed_data_dir, "ufo_fullset_formatted.csv"), index=False, header=True)

# %% [markdown]
# And now upload to S3 (assuming of course that our bucket exists):

# %%
s3 = boto3.resource("s3")
bucket_name = os.environ["s3_bucket"]
bucket = s3.Bucket(bucket_name)

target_key = "automl/input/ufo_fullset.csv"
bucket.upload_file(join(processed, "ufo_fullset_formatted.csv"), target_key)

# %% [markdown]
# ## AutoML job
#
# ### Config
#
# We now have to write some config for our AutoML job.

# %%
input_data_config = [{
    'DataSource': {
        'S3DataSource': {
            'S3DataType': 'S3Prefix',
            'S3Uri': 's3://{}/{}'.format(bucket_name, target_key)
        }
    },
    'TargetAttributeName': 'researchOutcome'
}]

output_data_config = {
    'S3OutputPath': 's3://{}/automl/output/'.format(bucket_name)
}

# %% [markdown]
# ### Create job

# %%
now = datetime.datetime.now()

# %%
int(now.timestamp())
# Out:
# 1601708912

# %%
auto_ml_job_name = 'automl-job-{}'.format(int(datetime.datetime.now().timestamp()))
print(auto_ml_job_name)
# Out:
# automl-job-1601709049

# %%
sm = boto3.client("sagemaker")
sm.create_auto_ml_job(AutoMLJobName=auto_ml_job_name,
                      InputDataConfig=input_data_config,
                      OutputDataConfig=output_data_config,
                      RoleArn=os.environ['sm_role'])
# Out:
# {'AutoMLJobArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:automl-job/automl-job-1601709049',
#  'ResponseMetadata': {'RequestId': '71b64b19-de23-4a2f-875f-934b949cf62f',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '71b64b19-de23-4a2f-875f-934b949cf62f',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '97',
#    'date': 'Sat, 03 Oct 2020 07:10:53 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Describe job

# %%
sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
# Out:
# {'AutoMLJobName': 'automl-job-1601709049',
#  'AutoMLJobArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:automl-job/automl-job-1601709049',
#  'InputDataConfig': [{'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix',
#      'S3Uri': 's3://acg-sm-demo-goyder/automl/input/ufo_fullset.csv'}},
#    'TargetAttributeName': 'researchOutcome'}],
#  'OutputDataConfig': {'S3OutputPath': 's3://acg-sm-demo-goyder/automl/output/'},
#  'RoleArn': 'arn:aws:iam::949012111517:role/sagemaker-role-acg-demo',
#  'CreationTime': datetime.datetime(2020, 10, 3, 15, 10, 52, 680000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2020, 10, 3, 15, 35, 48, 633000, tzinfo=tzlocal()),
#  'BestCandidate': {'CandidateName': 'tuning-job-1-93394821faf04a20b2-002-11ebe9ac',
#   'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:accuracy',
#    'Value': 0.9503200054168701},
#   'ObjectiveStatus': 'Succeeded',
#   'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:processing-job/db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257',
#     'CandidateStepName': 'db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/automl-job-dpp9-1-212202441f3c47a2895519791b5533ba9d422d970b774',
#     'CandidateStepName': 'automl-job-dpp9-1-212202441f3c47a2895519791b5533ba9d422d970b774'},
#    {'CandidateStepType': 'AWS::SageMaker::TransformJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:transform-job/automl-job-dpp9-rpb-1-175a6ff353f84d40b3ccff7972b6c675e839d7d27',
#     'CandidateStepName': 'automl-job-dpp9-rpb-1-175a6ff353f84d40b3ccff7972b6c675e839d7d27'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/tuning-job-1-93394821faf04a20b2-002-11ebe9ac',
#     'CandidateStepName': 'tuning-job-1-93394821faf04a20b2-002-11ebe9ac'}],
#   'CandidateStatus': 'Completed',
#   'InferenceContainers': [{'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp9-1-212202441f3c47a2895519791b5533ba9d422d970b774/output/model.tar.gz',
#     'Environment': {'AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF': '1',
#      'AUTOML_TRANSFORM_MODE': 'feature-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-xgboost:1.0-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/tuning/automl-job-dpp9-xgb/tuning-job-1-93394821faf04a20b2-002-11ebe9ac/output/model.tar.gz',
#     'Environment': {'MAX_CONTENT_LENGTH': '20971520',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp9-1-212202441f3c47a2895519791b5533ba9d422d970b774/output/model.tar.gz',
#     'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_INPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}}],
#   'CreationTime': datetime.datetime(2020, 10, 3, 15, 31, 42, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2020, 10, 3, 15, 33, 13, tzinfo=tzlocal()),
#   'LastModifiedTime': datetime.datetime(2020, 10, 3, 15, 35, 48, 609000, tzinfo=tzlocal())},
#  'AutoMLJobStatus': 'InProgress',
#  'AutoMLJobSecondaryStatus': 'ModelTuning',
#  'GenerateCandidateDefinitionsOnly': False,
#  'AutoMLJobArtifacts': {'CandidateDefinitionNotebookLocation': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/sagemaker-automl-candidates/pr-1-e9498de0093148ef9f1145f85bec89d6562e778c1f994b6ea3b1d69c9e/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb',
#   'DataExplorationNotebookLocation': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/sagemaker-automl-candidates/pr-1-e9498de0093148ef9f1145f85bec89d6562e778c1f994b6ea3b1d69c9e/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb'},
#  'ResolvedAttributes': {'AutoMLJobObjective': {'MetricName': 'Accuracy'},
#   'ProblemType': 'MulticlassClassification',
#   'CompletionCriteria': {'MaxCandidates': 250,
#    'MaxRuntimePerTrainingJobInSeconds': 86400,
#    'MaxAutoMLJobRuntimeInSeconds': 2592000}},
#  'ResponseMetadata': {'RequestId': 'ce7c7a9d-a6cb-48bc-a966-b10d25e13275',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'ce7c7a9d-a6cb-48bc-a966-b10d25e13275',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '4591',
#    'date': 'Sat, 03 Oct 2020 07:36:05 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Evaluate job
#
# We now pull data about the job from the AutoML API and evaluate.

# %%
candidates = sm.list_candidates_for_auto_ml_job(AutoMLJobName=auto_ml_job_name,
                                                SortBy='FinalObjectiveMetricValue'
                                               )['Candidates']

# %%
candidates
# Out:
# [{'CandidateName': 'tuning-job-1-93394821faf04a20b2-003-bc71d42c',
#   'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:accuracy',
#    'Value': 0.9503200054168701},
#   'ObjectiveStatus': 'Succeeded',
#   'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:processing-job/db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257',
#     'CandidateStepName': 'db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/automl-job-dpp1-1-e34f0a60d1594adc89a2db4294ec431bbdd9853bca814',
#     'CandidateStepName': 'automl-job-dpp1-1-e34f0a60d1594adc89a2db4294ec431bbdd9853bca814'},
#    {'CandidateStepType': 'AWS::SageMaker::TransformJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:transform-job/automl-job-dpp1-csv-1-633678ba706444f781e509f98078571b6f5b32845',
#     'CandidateStepName': 'automl-job-dpp1-csv-1-633678ba706444f781e509f98078571b6f5b32845'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/tuning-job-1-93394821faf04a20b2-003-bc71d42c',
#     'CandidateStepName': 'tuning-job-1-93394821faf04a20b2-003-bc71d42c'}],
#   'CandidateStatus': 'Completed',
#   'InferenceContainers': [{'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp1-1-e34f0a60d1594adc89a2db4294ec431bbdd9853bca814/output/model.tar.gz',
#     'Environment': {'AUTOML_TRANSFORM_MODE': 'feature-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-xgboost:1.0-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/tuning/automl-job-dpp1-xgb/tuning-job-1-93394821faf04a20b2-003-bc71d42c/output/model.tar.gz',
#     'Environment': {'MAX_CONTENT_LENGTH': '20971520',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp1-1-e34f0a60d1594adc89a2db4294ec431bbdd9853bca814/output/model.tar.gz',
#     'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_INPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}}],
#   'CreationTime': datetime.datetime(2020, 10, 3, 15, 31, 40, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2020, 10, 3, 15, 32, 51, tzinfo=tzlocal()),
#   'LastModifiedTime': datetime.datetime(2020, 10, 3, 15, 33, 3, 880000, tzinfo=tzlocal())},
#  {'CandidateName': 'tuning-job-1-93394821faf04a20b2-013-48c39ec5',
#   'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:accuracy',
#    'Value': 0.9503200054168701},
#   'ObjectiveStatus': 'Succeeded',
#   'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:processing-job/db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257',
#     'CandidateStepName': 'db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/automl-job-dpp1-1-e34f0a60d1594adc89a2db4294ec431bbdd9853bca814',
#     'CandidateStepName': 'automl-job-dpp1-1-e34f0a60d1594adc89a2db4294ec431bbdd9853bca814'},
#    {'CandidateStepType': 'AWS::SageMaker::TransformJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:transform-job/automl-job-dpp1-csv-1-633678ba706444f781e509f98078571b6f5b32845',
#     'CandidateStepName': 'automl-job-dpp1-csv-1-633678ba706444f781e509f98078571b6f5b32845'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/tuning-job-1-93394821faf04a20b2-013-48c39ec5',
#     'CandidateStepName': 'tuning-job-1-93394821faf04a20b2-013-48c39ec5'}],
#   'CandidateStatus': 'Completed',
#   'InferenceContainers': [{'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp1-1-e34f0a60d1594adc89a2db4294ec431bbdd9853bca814/output/model.tar.gz',
#     'Environment': {'AUTOML_TRANSFORM_MODE': 'feature-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-xgboost:1.0-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/tuning/automl-job-dpp1-xgb/tuning-job-1-93394821faf04a20b2-013-48c39ec5/output/model.tar.gz',
#     'Environment': {'MAX_CONTENT_LENGTH': '20971520',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp1-1-e34f0a60d1594adc89a2db4294ec431bbdd9853bca814/output/model.tar.gz',
#     'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_INPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}}],
#   'CreationTime': datetime.datetime(2020, 10, 3, 15, 34, 41, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2020, 10, 3, 15, 35, 49, tzinfo=tzlocal()),
#   'LastModifiedTime': datetime.datetime(2020, 10, 3, 15, 36, 6, 797000, tzinfo=tzlocal())},
#  {'CandidateName': 'tuning-job-1-93394821faf04a20b2-001-50d514f5',
#   'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:accuracy',
#    'Value': 0.9503200054168701},
#   'ObjectiveStatus': 'Succeeded',
#   'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:processing-job/db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257',
#     'CandidateStepName': 'db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/automl-job-dpp0-1-50c2db993d5c4aec8a270f940c4ab212cd5b25275b6f4',
#     'CandidateStepName': 'automl-job-dpp0-1-50c2db993d5c4aec8a270f940c4ab212cd5b25275b6f4'},
#    {'CandidateStepType': 'AWS::SageMaker::TransformJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:transform-job/automl-job-dpp0-rpb-1-dd9816116abb4d09aea1d52870ed3c097e47350f9',
#     'CandidateStepName': 'automl-job-dpp0-rpb-1-dd9816116abb4d09aea1d52870ed3c097e47350f9'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/tuning-job-1-93394821faf04a20b2-001-50d514f5',
#     'CandidateStepName': 'tuning-job-1-93394821faf04a20b2-001-50d514f5'}],
#   'CandidateStatus': 'Completed',
#   'InferenceContainers': [{'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp0-1-50c2db993d5c4aec8a270f940c4ab212cd5b25275b6f4/output/model.tar.gz',
#     'Environment': {'AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF': '1',
#      'AUTOML_TRANSFORM_MODE': 'feature-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-xgboost:1.0-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/tuning/automl-job-dpp0-xgb/tuning-job-1-93394821faf04a20b2-001-50d514f5/output/model.tar.gz',
#     'Environment': {'MAX_CONTENT_LENGTH': '20971520',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp0-1-50c2db993d5c4aec8a270f940c4ab212cd5b25275b6f4/output/model.tar.gz',
#     'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_INPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}}],
#   'CreationTime': datetime.datetime(2020, 10, 3, 15, 31, 37, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2020, 10, 3, 15, 32, 57, tzinfo=tzlocal()),
#   'LastModifiedTime': datetime.datetime(2020, 10, 3, 15, 33, 3, 880000, tzinfo=tzlocal())},
#  {'CandidateName': 'tuning-job-1-93394821faf04a20b2-002-11ebe9ac',
#   'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:accuracy',
#    'Value': 0.9503200054168701},
#   'ObjectiveStatus': 'Succeeded',
#   'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:processing-job/db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257',
#     'CandidateStepName': 'db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/automl-job-dpp9-1-212202441f3c47a2895519791b5533ba9d422d970b774',
#     'CandidateStepName': 'automl-job-dpp9-1-212202441f3c47a2895519791b5533ba9d422d970b774'},
#    {'CandidateStepType': 'AWS::SageMaker::TransformJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:transform-job/automl-job-dpp9-rpb-1-175a6ff353f84d40b3ccff7972b6c675e839d7d27',
#     'CandidateStepName': 'automl-job-dpp9-rpb-1-175a6ff353f84d40b3ccff7972b6c675e839d7d27'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/tuning-job-1-93394821faf04a20b2-002-11ebe9ac',
#     'CandidateStepName': 'tuning-job-1-93394821faf04a20b2-002-11ebe9ac'}],
#   'CandidateStatus': 'Completed',
#   'InferenceContainers': [{'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp9-1-212202441f3c47a2895519791b5533ba9d422d970b774/output/model.tar.gz',
#     'Environment': {'AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF': '1',
#      'AUTOML_TRANSFORM_MODE': 'feature-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-xgboost:1.0-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/tuning/automl-job-dpp9-xgb/tuning-job-1-93394821faf04a20b2-002-11ebe9ac/output/model.tar.gz',
#     'Environment': {'MAX_CONTENT_LENGTH': '20971520',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp9-1-212202441f3c47a2895519791b5533ba9d422d970b774/output/model.tar.gz',
#     'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_INPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}}],
#   'CreationTime': datetime.datetime(2020, 10, 3, 15, 31, 42, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2020, 10, 3, 15, 33, 13, tzinfo=tzlocal()),
#   'LastModifiedTime': datetime.datetime(2020, 10, 3, 15, 33, 22, 103000, tzinfo=tzlocal())},
#  {'CandidateName': 'tuning-job-1-93394821faf04a20b2-024-d00d5981',
#   'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:accuracy',
#    'Value': 0.9503200054168701},
#   'ObjectiveStatus': 'Succeeded',
#   'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:processing-job/db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257',
#     'CandidateStepName': 'db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/automl-job-dpp4-1-8345bc1c293b40ec87ebd22080aab442b1b854a90b234',
#     'CandidateStepName': 'automl-job-dpp4-1-8345bc1c293b40ec87ebd22080aab442b1b854a90b234'},
#    {'CandidateStepType': 'AWS::SageMaker::TransformJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:transform-job/automl-job-dpp4-rpb-1-6392d230890f4555ba41fc867c7afaf704c98c11e',
#     'CandidateStepName': 'automl-job-dpp4-rpb-1-6392d230890f4555ba41fc867c7afaf704c98c11e'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/tuning-job-1-93394821faf04a20b2-024-d00d5981',
#     'CandidateStepName': 'tuning-job-1-93394821faf04a20b2-024-d00d5981'}],
#   'CandidateStatus': 'Completed',
#   'InferenceContainers': [{'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp4-1-8345bc1c293b40ec87ebd22080aab442b1b854a90b234/output/model.tar.gz',
#     'Environment': {'AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF': '1',
#      'AUTOML_TRANSFORM_MODE': 'feature-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-xgboost:1.0-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/tuning/automl-job-dpp4-xgb/tuning-job-1-93394821faf04a20b2-024-d00d5981/output/model.tar.gz',
#     'Environment': {'MAX_CONTENT_LENGTH': '20971520',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp4-1-8345bc1c293b40ec87ebd22080aab442b1b854a90b234/output/model.tar.gz',
#     'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_INPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}}],
#   'CreationTime': datetime.datetime(2020, 10, 3, 15, 35, 59, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2020, 10, 3, 15, 36, 30, tzinfo=tzlocal()),
#   'LastModifiedTime': datetime.datetime(2020, 10, 3, 15, 36, 43, 573000, tzinfo=tzlocal())},
#  {'CandidateName': 'tuning-job-1-93394821faf04a20b2-005-f3a035cf',
#   'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:accuracy',
#    'Value': 0.9503200054168701},
#   'ObjectiveStatus': 'Succeeded',
#   'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:processing-job/db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257',
#     'CandidateStepName': 'db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/automl-job-dpp6-1-1438e2c0242a45efa96453462d665fdbf39ff54bbe3f4',
#     'CandidateStepName': 'automl-job-dpp6-1-1438e2c0242a45efa96453462d665fdbf39ff54bbe3f4'},
#    {'CandidateStepType': 'AWS::SageMaker::TransformJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:transform-job/automl-job-dpp6-rpb-1-d45cf0dafffb4de5a75e18be94a1d3102d964936a',
#     'CandidateStepName': 'automl-job-dpp6-rpb-1-d45cf0dafffb4de5a75e18be94a1d3102d964936a'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/tuning-job-1-93394821faf04a20b2-005-f3a035cf',
#     'CandidateStepName': 'tuning-job-1-93394821faf04a20b2-005-f3a035cf'}],
#   'CandidateStatus': 'Completed',
#   'InferenceContainers': [{'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp6-1-1438e2c0242a45efa96453462d665fdbf39ff54bbe3f4/output/model.tar.gz',
#     'Environment': {'AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF': '1',
#      'AUTOML_TRANSFORM_MODE': 'feature-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-xgboost:1.0-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/tuning/automl-job-dpp6-xgb/tuning-job-1-93394821faf04a20b2-005-f3a035cf/output/model.tar.gz',
#     'Environment': {'MAX_CONTENT_LENGTH': '20971520',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp6-1-1438e2c0242a45efa96453462d665fdbf39ff54bbe3f4/output/model.tar.gz',
#     'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_INPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}}],
#   'CreationTime': datetime.datetime(2020, 10, 3, 15, 31, 58, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2020, 10, 3, 15, 33, 6, tzinfo=tzlocal()),
#   'LastModifiedTime': datetime.datetime(2020, 10, 3, 15, 33, 22, 102000, tzinfo=tzlocal())},
#  {'CandidateName': 'tuning-job-1-93394821faf04a20b2-016-e197fd94',
#   'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:accuracy',
#    'Value': 0.9500399827957153},
#   'ObjectiveStatus': 'Succeeded',
#   'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:processing-job/db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257',
#     'CandidateStepName': 'db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/automl-job-dpp4-1-8345bc1c293b40ec87ebd22080aab442b1b854a90b234',
#     'CandidateStepName': 'automl-job-dpp4-1-8345bc1c293b40ec87ebd22080aab442b1b854a90b234'},
#    {'CandidateStepType': 'AWS::SageMaker::TransformJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:transform-job/automl-job-dpp4-rpb-1-6392d230890f4555ba41fc867c7afaf704c98c11e',
#     'CandidateStepName': 'automl-job-dpp4-rpb-1-6392d230890f4555ba41fc867c7afaf704c98c11e'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/tuning-job-1-93394821faf04a20b2-016-e197fd94',
#     'CandidateStepName': 'tuning-job-1-93394821faf04a20b2-016-e197fd94'}],
#   'CandidateStatus': 'Completed',
#   'InferenceContainers': [{'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp4-1-8345bc1c293b40ec87ebd22080aab442b1b854a90b234/output/model.tar.gz',
#     'Environment': {'AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF': '1',
#      'AUTOML_TRANSFORM_MODE': 'feature-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-xgboost:1.0-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/tuning/automl-job-dpp4-xgb/tuning-job-1-93394821faf04a20b2-016-e197fd94/output/model.tar.gz',
#     'Environment': {'MAX_CONTENT_LENGTH': '20971520',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp4-1-8345bc1c293b40ec87ebd22080aab442b1b854a90b234/output/model.tar.gz',
#     'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_INPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}}],
#   'CreationTime': datetime.datetime(2020, 10, 3, 15, 34, 37, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2020, 10, 3, 15, 35, 8, tzinfo=tzlocal()),
#   'LastModifiedTime': datetime.datetime(2020, 10, 3, 15, 35, 30, 4000, tzinfo=tzlocal())},
#  {'CandidateName': 'tuning-job-1-93394821faf04a20b2-004-2a6f44a1',
#   'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:accuracy',
#    'Value': 0.9500399827957153},
#   'ObjectiveStatus': 'Succeeded',
#   'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:processing-job/db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257',
#     'CandidateStepName': 'db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/automl-job-dpp5-1-802cced42a1a4a73acf2c2a03e79c18a3112a590ebf34',
#     'CandidateStepName': 'automl-job-dpp5-1-802cced42a1a4a73acf2c2a03e79c18a3112a590ebf34'},
#    {'CandidateStepType': 'AWS::SageMaker::TransformJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:transform-job/automl-job-dpp5-csv-1-ee4b24b707d2417d9293165502377e2219d3867be',
#     'CandidateStepName': 'automl-job-dpp5-csv-1-ee4b24b707d2417d9293165502377e2219d3867be'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/tuning-job-1-93394821faf04a20b2-004-2a6f44a1',
#     'CandidateStepName': 'tuning-job-1-93394821faf04a20b2-004-2a6f44a1'}],
#   'CandidateStatus': 'Completed',
#   'InferenceContainers': [{'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp5-1-802cced42a1a4a73acf2c2a03e79c18a3112a590ebf34/output/model.tar.gz',
#     'Environment': {'AUTOML_TRANSFORM_MODE': 'feature-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-xgboost:1.0-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/tuning/automl-job-dpp5-xgb/tuning-job-1-93394821faf04a20b2-004-2a6f44a1/output/model.tar.gz',
#     'Environment': {'MAX_CONTENT_LENGTH': '20971520',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp5-1-802cced42a1a4a73acf2c2a03e79c18a3112a590ebf34/output/model.tar.gz',
#     'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_INPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}}],
#   'CreationTime': datetime.datetime(2020, 10, 3, 15, 31, 40, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2020, 10, 3, 15, 32, 51, tzinfo=tzlocal()),
#   'LastModifiedTime': datetime.datetime(2020, 10, 3, 15, 33, 3, 880000, tzinfo=tzlocal())},
#  {'CandidateName': 'tuning-job-1-93394821faf04a20b2-011-485187d0',
#   'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:accuracy',
#    'Value': 0.9497600197792053},
#   'ObjectiveStatus': 'Succeeded',
#   'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:processing-job/db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257',
#     'CandidateStepName': 'db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/automl-job-dpp5-1-802cced42a1a4a73acf2c2a03e79c18a3112a590ebf34',
#     'CandidateStepName': 'automl-job-dpp5-1-802cced42a1a4a73acf2c2a03e79c18a3112a590ebf34'},
#    {'CandidateStepType': 'AWS::SageMaker::TransformJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:transform-job/automl-job-dpp5-csv-1-ee4b24b707d2417d9293165502377e2219d3867be',
#     'CandidateStepName': 'automl-job-dpp5-csv-1-ee4b24b707d2417d9293165502377e2219d3867be'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/tuning-job-1-93394821faf04a20b2-011-485187d0',
#     'CandidateStepName': 'tuning-job-1-93394821faf04a20b2-011-485187d0'}],
#   'CandidateStatus': 'Completed',
#   'InferenceContainers': [{'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp5-1-802cced42a1a4a73acf2c2a03e79c18a3112a590ebf34/output/model.tar.gz',
#     'Environment': {'AUTOML_TRANSFORM_MODE': 'feature-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-xgboost:1.0-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/tuning/automl-job-dpp5-xgb/tuning-job-1-93394821faf04a20b2-011-485187d0/output/model.tar.gz',
#     'Environment': {'MAX_CONTENT_LENGTH': '20971520',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp5-1-802cced42a1a4a73acf2c2a03e79c18a3112a590ebf34/output/model.tar.gz',
#     'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_INPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}}],
#   'CreationTime': datetime.datetime(2020, 10, 3, 15, 34, 36, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2020, 10, 3, 15, 35, 13, tzinfo=tzlocal()),
#   'LastModifiedTime': datetime.datetime(2020, 10, 3, 15, 35, 30, 5000, tzinfo=tzlocal())},
#  {'CandidateName': 'tuning-job-1-93394821faf04a20b2-029-9e0e927f',
#   'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:accuracy',
#    'Value': 0.9497600197792053},
#   'ObjectiveStatus': 'Succeeded',
#   'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:processing-job/db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257',
#     'CandidateStepName': 'db-1-6b6f57cfa3b244c1b008b9482ff383c3f2ce40b4087e46509551b15257'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/automl-job-dpp6-1-1438e2c0242a45efa96453462d665fdbf39ff54bbe3f4',
#     'CandidateStepName': 'automl-job-dpp6-1-1438e2c0242a45efa96453462d665fdbf39ff54bbe3f4'},
#    {'CandidateStepType': 'AWS::SageMaker::TransformJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:transform-job/automl-job-dpp6-rpb-1-d45cf0dafffb4de5a75e18be94a1d3102d964936a',
#     'CandidateStepName': 'automl-job-dpp6-rpb-1-d45cf0dafffb4de5a75e18be94a1d3102d964936a'},
#    {'CandidateStepType': 'AWS::SageMaker::TrainingJob',
#     'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-2:949012111517:training-job/tuning-job-1-93394821faf04a20b2-029-9e0e927f',
#     'CandidateStepName': 'tuning-job-1-93394821faf04a20b2-029-9e0e927f'}],
#   'CandidateStatus': 'Completed',
#   'InferenceContainers': [{'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp6-1-1438e2c0242a45efa96453462d665fdbf39ff54bbe3f4/output/model.tar.gz',
#     'Environment': {'AUTOML_SPARSE_ENCODE_RECORDIO_PROTOBUF': '1',
#      'AUTOML_TRANSFORM_MODE': 'feature-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-xgboost:1.0-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/tuning/automl-job-dpp6-xgb/tuning-job-1-93394821faf04a20b2-029-9e0e927f/output/model.tar.gz',
#     'Environment': {'MAX_CONTENT_LENGTH': '20971520',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}},
#    {'Image': '783357654285.dkr.ecr.ap-southeast-2.amazonaws.com/sagemaker-sklearn-automl:0.2-1-cpu-py3',
#     'ModelDataUrl': 's3://acg-sm-demo-goyder/automl/output/automl-job-1601709049/data-processor-models/automl-job-dpp6-1-1438e2c0242a45efa96453462d665fdbf39ff54bbe3f4/output/model.tar.gz',
#     'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform',
#      'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv',
#      'SAGEMAKER_INFERENCE_INPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label',
#      'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities',
#      'SAGEMAKER_PROGRAM': 'sagemaker_serve',
#      'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/sagemaker_serve.py'}}],
#   'CreationTime': datetime.datetime(2020, 10, 3, 15, 36, 43, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2020, 10, 3, 15, 37, 14, tzinfo=tzlocal()),
#   'LastModifiedTime': datetime.datetime(2020, 10, 3, 15, 37, 20, 622000, tzinfo=tzlocal())}]
